# %%
import pandas as pd

# %%
df = pd.read_csv("./nasa_global_landslide_catalog_point (1).csv")

# %%
df.head()
# Out:
#    OBJECTID                                     Shape  source_name  \
# 0   5525152   (107.45000000000005, 32.56250000000006)          AGU
# 1   5525153  (-122.66299999999995, 45.42000000000007)    Oregonian
# 2   5525154  (-75.35869999999994, -11.12949999999995)     CBS News
# 3   5525155   (81.70800000000008, 28.837800000000072)      Reuters
# 4   5525156  (123.89780000000007, 10.333600000000047)  The Freeman
#
#                                          source_link  event_id  \
# 0  https://blogs.agu.org/landslideblog/2008/10/14...       684
# 1  http://www.oregonlive.com/news/index.ssf/2009/...       956
# 2  https://www.cbsnews.com/news/dozens-missing-af...       973
# 3  https://in.reuters.com/article/idINIndia-41450...      1067
# 4  http://www.philstar.com/cebu-news/621414/lands...      2603
#
#             event_date event_time  \
# 0  2008-08-01 00:00:00        NaN
# 1  2009-01-02 02:00:00      02:00
# 2  2007-01-19 00:00:00        NaN
# 3  2009-07-31 00:00:00        NaN
# 4  2010-10-16 12:00:00      12:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
# 4                    sitio Bakilid in barangay Lahug
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
# 4  Another landslide in sitio Bakilid in barangay...
#
#                                 location_description  ... event_import_id  \
# 0      Sigou Village, Loufan County, Shanxi Province  ...             684
# 1                                Lake Oswego, Oregon  ...             956
# 2  San Ramon district, 195 miles northeast of the...  ...             973
# 3                                   Dailekh district  ...            1067
# 4                    sitio Bakilid in barangay Lahug  ...            2603
#
#   latitude longitude   country_name country_code  admin_division_name  \
# 0  32.5625  107.4500          China           CN              Shaanxi
# 1  45.4200 -122.6630  United States           US               Oregon
# 2 -11.1295  -75.3587           Peru           PE                Junín
# 3  28.8378   81.7080          Nepal           NP                Bheri
# 4  10.3336  123.8978    Philippines           PH                 Cebu
#
#    gazetteer_closest_point gazetteer_distance       submitted_date  \
# 0              Micang Shan              19.18  2014-04-01 00:00:00
# 1                 Portland               2.95  2014-04-01 00:00:00
# 2                San Ramon               2.77  2014-04-01 00:00:00
# 3                    Katti              11.78  2014-04-01 00:00:00
# 4                     Cebu               2.94  2014-04-01 00:00:00
#
#       last_edited_date
# 0  2021-09-04 04:47:42
# 1  2021-09-04 04:47:42
# 2  2021-09-04 04:47:42
# 3  2021-09-04 04:47:42
# 4  2021-09-04 04:47:42
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['OBJECTID', 'Shape', 'source_name', 'source_link', 'event_id',
#        'event_date', 'event_time', 'event_title', 'event_description',
#        'location_description', 'location_accuracy', 'landslide_category',
#        'landslide_trigger', 'landslide_size', 'landslide_setting',
#        'fatality_count', 'injury_count', 'storm_name', 'photo_link',
#        'comments', 'event_import_source', 'event_import_id', 'latitude',
#        'longitude', 'country_name', 'country_code', 'admin_division_name',
#        'gazetteer_closest_point', 'gazetteer_distance', 'submitted_date',
#        'last_edited_date'],
#       dtype='object')

# %%
nepal_data = df[df["country_name"] == 'Nepal']

# %%
nepal_data
# Out:
#        OBJECTID                                    Shape  \
# 3       5525155  (81.70800000000008, 28.837800000000072)
# 34      5525186  (83.98060000000004, 28.203900000000033)
# 35      5525187   (84.22790000000003, 27.94470000000007)
# 41      5525193  (85.71000000000004, 28.000000000000057)
# 42      5525194   (83.87910000000005, 28.10460000000006)
# ...         ...                                      ...
# 14147   5539299  (85.96782509500008, 27.978172511000025)
# 14275   5539427   (85.95418781700005, 27.97116855300004)
# 14394   5539546  (84.23280357300007, 28.456038842000055)
# 14409   5539561  (84.38187225900003, 28.296584059000054)
# 14418   5539570  (85.54504000000009, 27.829360000000065)
#
#                             source_name  \
# 3                               Reuters
# 34     SAARC Disaster Management Centre
# 35     SAARC Disaster Management Centre
# 41                             NBC News
# 42                              Reuters
# ...                                 ...
# 14147                           Science
# 14275                           Science
# 14394                       imagekhabar
# 14409                       imagekhabar
# 14418                The New York Times
#
#                                              source_link  event_id  \
# 3      https://in.reuters.com/article/idINIndia-41450...      1067
# 34                http://saarc-sdmc.nic.in/latest192.asp      1048
# 35                http://saarc-sdmc.nic.in/latest192.asp      1049
# 41     http://www.nbcnews.com/id/32186051/ns/us_news-...      1062
# 42     https://in.reuters.com/article/idINIndia-41450...      1065
# ...                                                  ...       ...
# 14147  https://science.sciencemag.org/content/362/641...     14287
# 14275  https://science.sciencemag.org/content/362/641...     14585
# 14394             https://www.imagekhabar.com/news/4691/     14534
# 14409             https://www.imagekhabar.com/news/4691/     14582
# 14418  https://www.cnn.com/2020/09/13/asia/nepal-land...     14488
#
#                 event_date event_time  \
# 3      2009-07-31 00:00:00        NaN
# 34     2009-07-02 03:00:00      03:00
# 35     2009-07-02 00:00:00        NaN
# 41     2009-07-27 00:00:00        NaN
# 42     2009-07-31 00:00:00        NaN
# ...                    ...        ...
# 14147  2016-07-06 00:58:51    unknown
# 14275  2016-07-05 18:38:09    unknown
# 14394  2018-09-13 03:29:08    unknown
# 14409  2018-09-13 01:29:00    unknown
# 14418  2020-09-13 05:00:00      10:00
#
#                                              event_title  \
# 3                                       Dailekh district
# 34                     Deurali VDC-8 in Kaski district,
# 35                       Dhapade VDC-5, Tanahun district
# 41      Takdoo village (250 km North east of Kathmandu)
# 42                   (Chitrebhanjyang) Syangja districts
# ...                                                  ...
# 14147                        Zhangzangbo River Landslide
# 14275                        Zhangzangbo River Landslide
# 14394                                  Lamjung Landslide
# 14409  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 14418  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                        event_description  \
# 3      One person was killed in Dailekh district, pol...
# 34     At least six people have died and two more hav...
# 35     At least six people have died and two more hav...
# 41     In the worst incident, at least 13 people were...
# 42     The landslides followed heavy monsoonal rains ...
# ...                                                  ...
# 14147  A moraine-dammed lake drained in association w...
# 14275  A moraine-dammed lake drained in association w...
# 14394  2 people died in a landslide at Khudi Pallotar...
# 14409  2 people died during medical treatment after b...
# 14418  In Nepal heavy rainfall causes landslide to oc...
#
#                                     location_description  ... event_import_id  \
# 3                                       Dailekh district  ...            1067
# 34                     Deurali VDC-8 in Kaski district,   ...            1048
# 35                       Dhapade VDC-5, Tanahun district  ...            1049
# 41      Takdoo village (250 km North east of Kathmandu)   ...            1062
# 42                   (Chitrebhanjyang) Syangja districts  ...            1065
# ...                                                  ...  ...             ...
# 14147  Zhangzangbo River, north of Tatopani, Tibet Au...  ...             NaN
# 14275  Zhangzangbo River, north of Tatopani, Tibet Au...  ...             NaN
# 14394                                     Lamjung, Nepal  ...             NaN
# 14409    Marsyangdi Rural Municipality-3, Lamjung, Nepal  ...             NaN
# 14418                      Sindhupalchok, Central Region  ...             NaN
#
#         latitude  longitude country_name country_code  admin_division_name  \
# 3      28.837800  81.708000        Nepal           NP                Bheri
# 34     28.203900  83.980600        Nepal           NP              Gandaki
# 35     27.944700  84.227900        Nepal           NP              Gandaki
# 41     28.000000  85.710000        Nepal           NP              Bagmati
# 42     28.104600  83.879100        Nepal           NP              Gandaki
# ...          ...        ...          ...          ...                  ...
# 14147  27.978173  85.967825        Nepal           NP              Bagmati
# 14275  27.971169  85.954188        Nepal           NP              Bagmati
# 14394  28.456039  84.232804        Nepal           NP              Gandaki
# 14409  28.296584  84.381872        Nepal           NP              Gandaki
# 14418  27.829360  85.545040        Nepal           NP              Bagmati
#
#        gazetteer_closest_point gazetteer_distance       submitted_date  \
# 3                        Katti              11.78  2014-04-01 00:00:00
# 34                        Gate              11.48  2014-04-01 00:00:00
# 35                        Gate              26.87  2014-04-01 00:00:00
# 41                   Barahbise              30.09  2014-04-01 00:00:00
# 42                     Bahakot               5.43  2014-04-01 00:00:00
# ...                        ...                ...                  ...
# 14147                Barahbise              22.08  2020-08-21 00:58:51
# 14275                Barahbise              20.96  2020-06-08 18:38:10
# 14394               Bagarchhap              13.13  2020-07-12 03:29:08
# 14409            Ma-hsun-ti Ho               6.36  2020-09-21 01:29:00
# 14418                  Bagmati              14.38  2020-09-17 23:14:38
#
#           last_edited_date
# 3      2021-09-04 04:47:42
# 34     2021-09-04 04:47:42
# 35     2021-09-04 04:47:42
# 41     2021-09-04 04:47:42
# 42     2021-09-04 04:47:42
# ...                    ...
# 14147  2021-09-04 04:58:51
# 14275  2021-09-04 04:58:51
# 14394  2021-09-04 04:58:51
# 14409  2021-09-04 04:58:51
# 14418  2021-09-04 04:58:51
#
# [587 rows x 31 columns]

# %%
nepal_data.columns
# Out:
# Index(['OBJECTID', 'Shape', 'source_name', 'source_link', 'event_id',
#        'event_date', 'event_time', 'event_title', 'event_description',
#        'location_description', 'location_accuracy', 'landslide_category',
#        'landslide_trigger', 'landslide_size', 'landslide_setting',
#        'fatality_count', 'injury_count', 'storm_name', 'photo_link',
#        'comments', 'event_import_source', 'event_import_id', 'latitude',
#        'longitude', 'country_name', 'country_code', 'admin_division_name',
#        'gazetteer_closest_point', 'gazetteer_distance', 'submitted_date',
#        'last_edited_date'],
#       dtype='object')

# %%
features = ['event_date', 'event_title', 'location_description', 'landslide_category',
       'landslide_trigger', 'landslide_size', 'landslide_setting',
       'fatality_count', 'injury_count', 'latitude',
       'longitude']

# %%
nepal_data = nepal_data[features]

# %%
nepal_data.head()
# Out:
#              event_date                                       event_title  \
# 3   2009-07-31 00:00:00                                  Dailekh district
# 34  2009-07-02 03:00:00                 Deurali VDC-8 in Kaski district,
# 35  2009-07-02 00:00:00                   Dhapade VDC-5, Tanahun district
# 41  2009-07-27 00:00:00  Takdoo village (250 km North east of Kathmandu)
# 42  2009-07-31 00:00:00               (Chitrebhanjyang) Syangja districts
#
#                                 location_description landslide_category  \
# 3                                   Dailekh district          landslide
# 34                 Deurali VDC-8 in Kaski district,           landslide
# 35                   Dhapade VDC-5, Tanahun district          landslide
# 41  Takdoo village (250 km North east of Kathmandu)           landslide
# 42               (Chitrebhanjyang) Syangja districts          landslide
#
#    landslide_trigger landslide_size landslide_setting  fatality_count  \
# 3            monsoon         medium           unknown             1.0
# 34           monsoon         medium           unknown             3.0
# 35           monsoon         medium           unknown             2.0
# 41           monsoon          large           unknown            13.0
# 42           monsoon         medium           unknown             5.0
#
#     injury_count  latitude  longitude
# 3            NaN   28.8378    81.7080
# 34           NaN   28.2039    83.9806
# 35           NaN   27.9447    84.2279
# 41           NaN   28.0000    85.7100
# 42           NaN   28.1046    83.8791

# %%
nepal_data['landslide_setting'].unique()
# Out:
# array(['unknown', 'above_road', 'natural_slope', 'above_river', 'other',
#        'below_road', 'urban', 'burned_area', 'deforested_slope', 'mine',
#        'engineered_slope'], dtype=object)

# %%
nepal_data = nepal_data.drop(['landslide_category', 'landslide_trigger', 'landslide_setting'], axis=1)

# %%
nepal_data
# Out:
#                 event_date                                        event_title  \
# 3      2009-07-31 00:00:00                                   Dailekh district
# 34     2009-07-02 03:00:00                  Deurali VDC-8 in Kaski district,
# 35     2009-07-02 00:00:00                    Dhapade VDC-5, Tanahun district
# 41     2009-07-27 00:00:00   Takdoo village (250 km North east of Kathmandu)
# 42     2009-07-31 00:00:00                (Chitrebhanjyang) Syangja districts
# ...                    ...                                                ...
# 14147  2016-07-06 00:58:51                        Zhangzangbo River Landslide
# 14275  2016-07-05 18:38:09                        Zhangzangbo River Landslide
# 14394  2018-09-13 03:29:08                                  Lamjung Landslide
# 14409  2018-09-13 01:29:00  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 14418  2020-09-13 05:00:00  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                     location_description landslide_size  \
# 3                                       Dailekh district         medium
# 34                     Deurali VDC-8 in Kaski district,          medium
# 35                       Dhapade VDC-5, Tanahun district         medium
# 41      Takdoo village (250 km North east of Kathmandu)           large
# 42                   (Chitrebhanjyang) Syangja districts         medium
# ...                                                  ...            ...
# 14147  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 14275  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 14394                                     Lamjung, Nepal          large
# 14409    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 14418                      Sindhupalchok, Central Region          small
#
#        fatality_count  injury_count   latitude  longitude
# 3                 1.0           NaN  28.837800  81.708000
# 34                3.0           NaN  28.203900  83.980600
# 35                2.0           NaN  27.944700  84.227900
# 41               13.0           NaN  28.000000  85.710000
# 42                5.0           NaN  28.104600  83.879100
# ...               ...           ...        ...        ...
# 14147             NaN           NaN  27.978173  85.967825
# 14275             NaN           NaN  27.971169  85.954188
# 14394             2.0           NaN  28.456039  84.232804
# 14409             2.0           NaN  28.296584  84.381872
# 14418            11.0           0.0  27.829360  85.545040
#
# [587 rows x 8 columns]

# %%
nepal_data['fatality_count'] = nepal_data['fatality_count'].fillna(0)
nepal_data['injury_count'] = nepal_data['injury_count'].fillna(0)

# %%
nepal_data
# Out:
#                 event_date                                        event_title  \
# 3      2009-07-31 00:00:00                                   Dailekh district
# 34     2009-07-02 03:00:00                  Deurali VDC-8 in Kaski district,
# 35     2009-07-02 00:00:00                    Dhapade VDC-5, Tanahun district
# 41     2009-07-27 00:00:00   Takdoo village (250 km North east of Kathmandu)
# 42     2009-07-31 00:00:00                (Chitrebhanjyang) Syangja districts
# ...                    ...                                                ...
# 14147  2016-07-06 00:58:51                        Zhangzangbo River Landslide
# 14275  2016-07-05 18:38:09                        Zhangzangbo River Landslide
# 14394  2018-09-13 03:29:08                                  Lamjung Landslide
# 14409  2018-09-13 01:29:00  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 14418  2020-09-13 05:00:00  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                     location_description landslide_size  \
# 3                                       Dailekh district         medium
# 34                     Deurali VDC-8 in Kaski district,          medium
# 35                       Dhapade VDC-5, Tanahun district         medium
# 41      Takdoo village (250 km North east of Kathmandu)           large
# 42                   (Chitrebhanjyang) Syangja districts         medium
# ...                                                  ...            ...
# 14147  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 14275  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 14394                                     Lamjung, Nepal          large
# 14409    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 14418                      Sindhupalchok, Central Region          small
#
#        fatality_count  injury_count   latitude  longitude
# 3                 1.0           0.0  28.837800  81.708000
# 34                3.0           0.0  28.203900  83.980600
# 35                2.0           0.0  27.944700  84.227900
# 41               13.0           0.0  28.000000  85.710000
# 42                5.0           0.0  28.104600  83.879100
# ...               ...           ...        ...        ...
# 14147             0.0           0.0  27.978173  85.967825
# 14275             0.0           0.0  27.971169  85.954188
# 14394             2.0           0.0  28.456039  84.232804
# 14409             2.0           0.0  28.296584  84.381872
# 14418            11.0           0.0  27.829360  85.545040
#
# [587 rows x 8 columns]

# %%
nepal_data['event_date']
# Out:
# 3        2009-07-31 00:00:00
# 34       2009-07-02 03:00:00
# 35       2009-07-02 00:00:00
# 41       2009-07-27 00:00:00
# 42       2009-07-31 00:00:00
#                 ...
# 14147    2016-07-06 00:58:51
# 14275    2016-07-05 18:38:09
# 14394    2018-09-13 03:29:08
# 14409    2018-09-13 01:29:00
# 14418    2020-09-13 05:00:00
# Name: event_date, Length: 587, dtype: object

# %%
nepal_data = nepal_data.reset_index()

# %%
nepal_data = nepal_data.drop(['index'], axis=1)

# %%
nepal_data
# Out:
#               event_date                                        event_title  \
# 0    2009-07-31 00:00:00                                   Dailekh district
# 1    2009-07-02 03:00:00                  Deurali VDC-8 in Kaski district,
# 2    2009-07-02 00:00:00                    Dhapade VDC-5, Tanahun district
# 3    2009-07-27 00:00:00   Takdoo village (250 km North east of Kathmandu)
# 4    2009-07-31 00:00:00                (Chitrebhanjyang) Syangja districts
# ..                   ...                                                ...
# 582  2016-07-06 00:58:51                        Zhangzangbo River Landslide
# 583  2016-07-05 18:38:09                        Zhangzangbo River Landslide
# 584  2018-09-13 03:29:08                                  Lamjung Landslide
# 585  2018-09-13 01:29:00  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 586  2020-09-13 05:00:00  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                   location_description landslide_size  \
# 0                                     Dailekh district         medium
# 1                    Deurali VDC-8 in Kaski district,          medium
# 2                      Dhapade VDC-5, Tanahun district         medium
# 3     Takdoo village (250 km North east of Kathmandu)           large
# 4                  (Chitrebhanjyang) Syangja districts         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 583  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 584                                     Lamjung, Nepal          large
# 585    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 586                      Sindhupalchok, Central Region          small
#
#      fatality_count  injury_count   latitude  longitude
# 0               1.0           0.0  28.837800  81.708000
# 1               3.0           0.0  28.203900  83.980600
# 2               2.0           0.0  27.944700  84.227900
# 3              13.0           0.0  28.000000  85.710000
# 4               5.0           0.0  28.104600  83.879100
# ..              ...           ...        ...        ...
# 582             0.0           0.0  27.978173  85.967825
# 583             0.0           0.0  27.971169  85.954188
# 584             2.0           0.0  28.456039  84.232804
# 585             2.0           0.0  28.296584  84.381872
# 586            11.0           0.0  27.829360  85.545040
#
# [587 rows x 8 columns]

# %%
dates = nepal_data['event_date']

# %%
dates
# Out:
# 0      2009-07-31 00:00:00
# 1      2009-07-02 03:00:00
# 2      2009-07-02 00:00:00
# 3      2009-07-27 00:00:00
# 4      2009-07-31 00:00:00
#               ...
# 582    2016-07-06 00:58:51
# 583    2016-07-05 18:38:09
# 584    2018-09-13 03:29:08
# 585    2018-09-13 01:29:00
# 586    2020-09-13 05:00:00
# Name: event_date, Length: 587, dtype: object

# %%
year = []
for index in dates.index:
    year.append(dates[index][0:4])

# %%
year
# Out:
# ['2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2013',
#  '2013',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2008',
#  '2015',
#  '2016',
#  '2011',
#  '2016',
#  '2014',
#  '2015',
#  '2010',
#  '2007',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2011',
#  '2013',
#  '2009',
#  '2015',
#  '2015',
#  '2010',
#  '2010',
#  '2011',
#  '2009',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2015',
#  '2013',
#  '2013',
#  '2013',
#  '2011',
#  '2010',
#  '2013',
#  '2015',
#  '2007',
#  '2010',
#  '2014',
#  '2013',
#  '2016',
#  '2016',
#  '2010',
#  '2011',
#  '2008',
#  '2011',
#  '2010',
#  '2013',
#  '2015',
#  '2010',
#  '2015',
#  '2013',
#  '2013',
#  '2007',
#  '2015',
#  '2011',
#  '2009',
#  '2012',
#  '2016',
#  '2011',
#  '2016',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2013',
#  '2013',
#  '2010',
#  '2009',
#  '2011',
#  '2016',
#  '2007',
#  '2015',
#  '2015',
#  '2015',
#  '2013',
#  '2013',
#  '2010',
#  '2010',
#  '2010',
#  '2016',
#  '2015',
#  '2011',
#  '2013',
#  '2016',
#  '2010',
#  '2007',
#  '2007',
#  '2011',
#  '2011',
#  '2012',
#  '2014',
#  '2013',
#  '2013',
#  '2016',
#  '2014',
#  '2010',
#  '2013',
#  '2016',
#  '2013',
#  '2010',
#  '2008',
#  '2014',
#  '2011',
#  '2014',
#  '2015',
#  '2016',
#  '2007',
#  '2011',
#  '2008',
#  '2010',
#  '2007',
#  '2014',
#  '2015',
#  '2010',
#  '2016',
#  '2010',
#  '2016',
#  '2009',
#  '2011',
#  '2015',
#  '2009',
#  '2010',
#  '2008',
#  '2011',
#  '2014',
#  '2014',
#  '2009',
#  '2014',
#  '2012',
#  '2007',
#  '2014',
#  '2016',
#  '2016',
#  '2009',
#  '2012',
#  '2007',
#  '2012',
#  '2016',
#  '2014',
#  '2007',
#  '2014',
#  '2014',
#  '2014',
#  '2007',
#  '2012',
#  '2010',
#  '2015',
#  '2010',
#  '2014',
#  '2010',
#  '2016',
#  '2009',
#  '2014',
#  '2010',
#  '2015',
#  '2013',
#  '2010',
#  '2016',
#  '2015',
#  '2015',
#  '2016',
#  '2013',
#  '2011',
#  '2013',
#  '2010',
#  '2016',
#  '2014',
#  '2012',
#  '2011',
#  '2010',
#  '2013',
#  '2015',
#  '2015',
#  '2016',
#  '2014',
#  '2016',
#  '2015',
#  '2016',
#  '2013',
#  '2012',
#  '2016',
#  '2014',
#  '2015',
#  '2011',
#  '2008',
#  '2009',
#  '2016',
#  '2015',
#  '2015',
#  '2016',
#  '2015',
#  '2013',
#  '2015',
#  '2011',
#  '2008',
#  '2010',
#  '2010',
#  '2010',
#  '2016',
#  '2016',
#  '2010',
#  '2010',
#  '2011',
#  '2016',
#  '2007',
#  '2008',
#  '2010',
#  '2015',
#  '2013',
#  '2016',
#  '2015',
#  '2016',
#  '2009',
#  '2013',
#  '2014',
#  '2010',
#  '2011',
#  '2010',
#  '2012',
#  '2016',
#  '2012',
#  '2010',
#  '2015',
#  '2010',
#  '2013',
#  '2011',
#  '2011',
#  '2009',
#  '2016',
#  '2012',
#  '2013',
#  '2011',
#  '2010',
#  '2016',
#  '2015',
#  '2011',
#  '2010',
#  '2010',
#  '2011',
#  '2009',
#  '2016',
#  '2010',
#  '2010',
#  '2010',
#  '2011',
#  '2011',
#  '2014',
#  '2010',
#  '2015',
#  '2016',
#  '2013',
#  '2008',
#  '2014',
#  '2013',
#  '2016',
#  '2009',
#  '2013',
#  '2010',
#  '2007',
#  '2007',
#  '2016',
#  '2013',
#  '2008',
#  '2016',
#  '2016',
#  '2007',
#  '2015',
#  '2015',
#  '2011',
#  '2013',
#  '2014',
#  '2013',
#  '2014',
#  '2007',
#  '2015',
#  '2016',
#  '2010',
#  '2010',
#  '2010',
#  '2016',
#  '2013',
#  '2016',
#  '2016',
#  '2007',
#  '2009',
#  '2013',
#  '2009',
#  '2010',
#  '2011',
#  '2008',
#  '2013',
#  '2008',
#  '2014',
#  '2012',
#  '2013',
#  '2007',
#  '2014',
#  '2010',
#  '2014',
#  '2015',
#  '2013',
#  '2008',
#  '2014',
#  '2010',
#  '2008',
#  '2013',
#  '2015',
#  '2014',
#  '2008',
#  '2014',
#  '2010',
#  '2015',
#  '2015',
#  '2008',
#  '2009',
#  '2010',
#  '2015',
#  '2016',
#  '2011',
#  '2010',
#  '2010',
#  '2013',
#  '2008',
#  '2012',
#  '2007',
#  '2008',
#  '2010',
#  '2016',
#  '2008',
#  '2011',
#  '2015',
#  '2011',
#  '2013',
#  '2015',
#  '2017',
#  '2015',
#  '2016',
#  '2008',
#  '2008',
#  '2014',
#  '2011',
#  '2013',
#  '2009',
#  '2007',
#  '2011',
#  '2013',
#  '2010',
#  '2014',
#  '2013',
#  '2013',
#  '2015',
#  '2016',
#  '2007',
#  '2015',
#  '2011',
#  '2010',
#  '2011',
#  '2014',
#  '2013',
#  '2015',
#  '2013',
#  '2016',
#  '2013',
#  '2015',
#  '2012',
#  '2012',
#  '2015',
#  '2011',
#  '2010',
#  '2015',
#  '2016',
#  '2009',
#  '2013',
#  '2011',
#  '2016',
#  '2011',
#  '2013',
#  '2009',
#  '2016',
#  '2011',
#  '2013',
#  '2015',
#  '2013',
#  '2011',
#  '2010',
#  '2015',
#  '2008',
#  '2015',
#  '2011',
#  '2010',
#  '2014',
#  '2016',
#  '2010',
#  '2011',
#  '2013',
#  '2011',
#  '2016',
#  '2008',
#  '2013',
#  '2016',
#  '2009',
#  '2010',
#  '2007',
#  '2011',
#  '2008',
#  '2013',
#  '2014',
#  '2010',
#  '2014',
#  '2007',
#  '2015',
#  '2014',
#  '2016',
#  '2011',
#  '2014',
#  '2016',
#  '2007',
#  '2009',
#  '2016',
#  '2007',
#  '2013',
#  '2008',
#  '2016',
#  '2011',
#  '2013',
#  '2011',
#  '2016',
#  '2014',
#  '2016',
#  '2013',
#  '2016',
#  '2008',
#  '2011',
#  '2014',
#  '2010',
#  '2009',
#  '2014',
#  '2007',
#  '2008',
#  '2010',
#  '2015',
#  '2014',
#  '2008',
#  '2016',
#  '2007',
#  '2014',
#  '2010',
#  '2011',
#  '2014',
#  '2013',
#  '2011',
#  '2016',
#  '2013',
#  '2010',
#  '2010',
#  '2011',
#  '2016',
#  '2008',
#  '2015',
#  '2011',
#  '2013',
#  '2008',
#  '2014',
#  '2008',
#  '2011',
#  '2010',
#  '2008',
#  '2008',
#  '2015',
#  '2013',
#  '2009',
#  '2015',
#  '2007',
#  '2012',
#  '2013',
#  '2017',
#  '2016',
#  '2013',
#  '2014',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2016',
#  '2016',
#  '2018',
#  '2018',
#  '2020']

# %%
nepal_data['event_year'] = year
for index in dates.index:
    dates[index] = dates[index][5:7]
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
nepal_data
# Out:
#     event_date                                        event_title  \
# 0           07                                   Dailekh district
# 1           07                  Deurali VDC-8 in Kaski district,
# 2           07                    Dhapade VDC-5, Tanahun district
# 3           07   Takdoo village (250 km North east of Kathmandu)
# 4           07                (Chitrebhanjyang) Syangja districts
# ..         ...                                                ...
# 582         07                        Zhangzangbo River Landslide
# 583         07                        Zhangzangbo River Landslide
# 584         09                                  Lamjung Landslide
# 585         09  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 586         09  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                   location_description landslide_size  \
# 0                                     Dailekh district         medium
# 1                    Deurali VDC-8 in Kaski district,          medium
# 2                      Dhapade VDC-5, Tanahun district         medium
# 3     Takdoo village (250 km North east of Kathmandu)           large
# 4                  (Chitrebhanjyang) Syangja districts         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 583  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 584                                     Lamjung, Nepal          large
# 585    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 586                      Sindhupalchok, Central Region          small
#
#      fatality_count  injury_count   latitude  longitude event_year
# 0               1.0           0.0  28.837800  81.708000       2009
# 1               3.0           0.0  28.203900  83.980600       2009
# 2               2.0           0.0  27.944700  84.227900       2009
# 3              13.0           0.0  28.000000  85.710000       2009
# 4               5.0           0.0  28.104600  83.879100       2009
# ..              ...           ...        ...        ...        ...
# 582             0.0           0.0  27.978173  85.967825       2016
# 583             0.0           0.0  27.971169  85.954188       2016
# 584             2.0           0.0  28.456039  84.232804       2018
# 585             2.0           0.0  28.296584  84.381872       2018
# 586            11.0           0.0  27.829360  85.545040       2020
#
# [587 rows x 9 columns]

# %%
nepal_data.rename(columns = {'event_date':'event_month'}, inplace = True)

# %%
nepal_data
# Out:
#     event_month                                        event_title  \
# 0            07                                   Dailekh district
# 1            07                  Deurali VDC-8 in Kaski district,
# 2            07                    Dhapade VDC-5, Tanahun district
# 3            07   Takdoo village (250 km North east of Kathmandu)
# 4            07                (Chitrebhanjyang) Syangja districts
# ..          ...                                                ...
# 582          07                        Zhangzangbo River Landslide
# 583          07                        Zhangzangbo River Landslide
# 584          09                                  Lamjung Landslide
# 585          09  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 586          09  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                   location_description landslide_size  \
# 0                                     Dailekh district         medium
# 1                    Deurali VDC-8 in Kaski district,          medium
# 2                      Dhapade VDC-5, Tanahun district         medium
# 3     Takdoo village (250 km North east of Kathmandu)           large
# 4                  (Chitrebhanjyang) Syangja districts         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 583  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 584                                     Lamjung, Nepal          large
# 585    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 586                      Sindhupalchok, Central Region          small
#
#      fatality_count  injury_count   latitude  longitude event_year
# 0               1.0           0.0  28.837800  81.708000       2009
# 1               3.0           0.0  28.203900  83.980600       2009
# 2               2.0           0.0  27.944700  84.227900       2009
# 3              13.0           0.0  28.000000  85.710000       2009
# 4               5.0           0.0  28.104600  83.879100       2009
# ..              ...           ...        ...        ...        ...
# 582             0.0           0.0  27.978173  85.967825       2016
# 583             0.0           0.0  27.971169  85.954188       2016
# 584             2.0           0.0  28.456039  84.232804       2018
# 585             2.0           0.0  28.296584  84.381872       2018
# 586            11.0           0.0  27.829360  85.545040       2020
#
# [587 rows x 9 columns]

# %%
nepal_data.columns
# Out:
# Index(['event_month', 'event_title', 'location_description', 'landslide_size',
#        'fatality_count', 'injury_count', 'latitude', 'longitude',
#        'event_year'],
#       dtype='object')

# %%
column_names = ['event_year', 'event_month', 'event_title', 'location_description', 'landslide_size',
       'fatality_count', 'injury_count', 'latitude', 'longitude',]

nepal_data = nepal_data.reindex(columns=column_names)

# %%
nepal_data
# Out:
#     event_year event_month                                        event_title  \
# 0         2009          07                                   Dailekh district
# 1         2009          07                  Deurali VDC-8 in Kaski district,
# 2         2009          07                    Dhapade VDC-5, Tanahun district
# 3         2009          07   Takdoo village (250 km North east of Kathmandu)
# 4         2009          07                (Chitrebhanjyang) Syangja districts
# ..         ...         ...                                                ...
# 582       2016          07                        Zhangzangbo River Landslide
# 583       2016          07                        Zhangzangbo River Landslide
# 584       2018          09                                  Lamjung Landslide
# 585       2018          09  Marsyangdi Rural Municipality-3, Lamjung Lands...
# 586       2020          09  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                   location_description landslide_size  \
# 0                                     Dailekh district         medium
# 1                    Deurali VDC-8 in Kaski district,          medium
# 2                      Dhapade VDC-5, Tanahun district         medium
# 3     Takdoo village (250 km North east of Kathmandu)           large
# 4                  (Chitrebhanjyang) Syangja districts         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 583  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 584                                     Lamjung, Nepal          large
# 585    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 586                      Sindhupalchok, Central Region          small
#
#      fatality_count  injury_count   latitude  longitude
# 0               1.0           0.0  28.837800  81.708000
# 1               3.0           0.0  28.203900  83.980600
# 2               2.0           0.0  27.944700  84.227900
# 3              13.0           0.0  28.000000  85.710000
# 4               5.0           0.0  28.104600  83.879100
# ..              ...           ...        ...        ...
# 582             0.0           0.0  27.978173  85.967825
# 583             0.0           0.0  27.971169  85.954188
# 584             2.0           0.0  28.456039  84.232804
# 585             2.0           0.0  28.296584  84.381872
# 586            11.0           0.0  27.829360  85.545040
#
# [587 rows x 9 columns]

# %%
test = nepal_data.copy()
test['event_title'] = test['event_title'].astype(str)
districts = test['event_title']

# %%
districts
# Out:
# 0                                       Dailekh district
# 1                      Deurali VDC-8 in Kaski district,
# 2                        Dhapade VDC-5, Tanahun district
# 3       Takdoo village (250 km North east of Kathmandu)
# 4                    (Chitrebhanjyang) Syangja districts
#                              ...
# 582                          Zhangzangbo River Landslide
# 583                          Zhangzangbo River Landslide
# 584                                    Lamjung Landslide
# 585    Marsyangdi Rural Municipality-3, Lamjung Lands...
# 586    At Least 11 Dead as Nepal Landslides Destroy H...
# Name: event_title, Length: 587, dtype: object

# %%
nepal_districts = ["Achham","Arghakhanchi","Baglung","Baitadi","Bajhang","Bajura","Banke","Bara","Bardiya","Bhaktapur","Bhojpur","Chitwan","Dadeldhura","Dailekh","Dang","Darchula","Dhading","Dhankuta","Dhanusa","Dolakha","Dolpa","Doti","Gorkha","Gulmi","Humla","Ilam","Jajarkot","Jhapa","Jumla","Kailali","Kalikot","Kanchanpur","Kapilvastu","Kaski","Kathmandu","Kavrepalanchok","Khotang","Lalitpur","Lamjung","Mahottari","Makawanpur","Manang","Morang","Mugu","Mustang","Myagdi","Nawalparasi","Nuwakot","Okhaldhunga","Palpa","Panchthar","Parbat","Parsa","Pyuthan","Ramechhap","Rasuwa","Rautahat","Rolpa","Rukum","Rupandehi","Salyan","Sankhuwasabha","Saptari","Sarlahi","Sindhuli","Sindhupalchok","Siraha","Solukhumbu","Sunsari","Surkhet","Syangja","Tanahu","Taplejung","Terhathum","Udayapur"]

# %%
for index in districts.index:
    for district in nepal_districts:
        if district in districts[index]:
            districts[index] = district
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
districts
# Out:
# 0                                                Dailekh
# 1                                                  Kaski
# 2                                                 Tanahu
# 3                                              Kathmandu
# 4                                                Syangja
#                              ...
# 582                          Zhangzangbo River Landslide
# 583                          Zhangzangbo River Landslide
# 584                                              Lamjung
# 585                                              Lamjung
# 586    At Least 11 Dead as Nepal Landslides Destroy H...
# Name: event_title, Length: 587, dtype: object

# %%
test
# Out:
#     event_year event_month                                        event_title  \
# 0         2009          07                                            Dailekh
# 1         2009          07                                              Kaski
# 2         2009          07                                             Tanahu
# 3         2009          07                                          Kathmandu
# 4         2009          07                                            Syangja
# ..         ...         ...                                                ...
# 582       2016          07                        Zhangzangbo River Landslide
# 583       2016          07                        Zhangzangbo River Landslide
# 584       2018          09                                            Lamjung
# 585       2018          09                                            Lamjung
# 586       2020          09  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                   location_description landslide_size  \
# 0                                     Dailekh district         medium
# 1                    Deurali VDC-8 in Kaski district,          medium
# 2                      Dhapade VDC-5, Tanahun district         medium
# 3     Takdoo village (250 km North east of Kathmandu)           large
# 4                  (Chitrebhanjyang) Syangja districts         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 583  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 584                                     Lamjung, Nepal          large
# 585    Marsyangdi Rural Municipality-3, Lamjung, Nepal          large
# 586                      Sindhupalchok, Central Region          small
#
#      fatality_count  injury_count   latitude  longitude
# 0               1.0           0.0  28.837800  81.708000
# 1               3.0           0.0  28.203900  83.980600
# 2               2.0           0.0  27.944700  84.227900
# 3              13.0           0.0  28.000000  85.710000
# 4               5.0           0.0  28.104600  83.879100
# ..              ...           ...        ...        ...
# 582             0.0           0.0  27.978173  85.967825
# 583             0.0           0.0  27.971169  85.954188
# 584             2.0           0.0  28.456039  84.232804
# 585             2.0           0.0  28.296584  84.381872
# 586            11.0           0.0  27.829360  85.545040
#
# [587 rows x 9 columns]

# %%
test['location_description'].unique()
# Out:
# array(['Dailekh district', 'Deurali VDC-8 in Kaski district, ',
#        'Dhapade VDC-5, Tanahun district',
#        'Takdoo village (250 km North east of Kathmandu) ',
#        '(Chitrebhanjyang) Syangja districts',
#        'Rural roads in Arghakhanchi', 'Rural Roads in Baglung',
#        'Rural Roads in Gulmi', 'Ruinibang of Sulichowr VDC,Rolpa',
#        'Rapti Highway, Salyan District, Midwestern Region',
#        'Rapti Highway, Rukum District, Midwestern Region',
#        'Paintedanda near Kharanephant in Lekhnath Municipality-4 of Kaski district',
#        'Narayangadh-Muglin road section, Chitwan, Nepal',
#        'Gajuri, Dhading, Nepal', 'Taplejung, Nepal',
#        'Pasang Lhamu Highway', 'Bhojpur, Kulung, Nepal',
#        'Bhagawati, Myagdi, Nepal',
#        'Bhotekoshi Rural Municpality, Sindhupalchok District, Nepal',
#        'Pasang Lhamu Highway, Nepal', 'Dharka, Dhading, Nepal',
#        'Jugu, Nepal', 'Galeshwor, Beni, Nepal', 'Talladehi, Nepal',
#        'Mugu, Nepal', 'Lamjung, Nepal', 'School',
#        'Mechi highway near the Khokse River at Dokhu area of Phuling Municipality in Taplejung district.',
#        'Rajwara, Gaumukhi Rural Municipality, Nepal',
#        'Narayangadh-Muglin, Chitwan, Central Development Region, Nepal',
#        'Matepani Gupta monastery, Pokhara, Nepal',
#        'Ipa Panchakanya, Makawanpur, Nepal',
#        'Hosrangdi, Mahashila Rural Municipality, Nepal',
#        'Chyotchyot, Lamabagar, Dolakha, Nepal',
#        'Lamachaur, Pokhara, Nepal', 'Tanahu, Risiti, Nepal',
#        'Amden (??), Myadlung Municipality, Eastern Development Region, Nepal',
#        'Jubitha, Nepal', 'Pasryanga cliff (??), Pokhara, Nepal',
#        'Muglin Road, Chitwan, Nepal',
#        "Four members of a single family were buried alive after torrential rain triggered a landslide at Kevarebhanjyang – 7 of Syangja last night.   The landslide fell on a house at 1 am killing Chandra Kumari Saru, 78, her grand- daughter, Humkala Mashrangi, 30, Humkala's seven-year-old daughter Punam Mashrangi and one-year-old son Milan Mashrangi, said Inspector, Uttam Prakash Baral, of Ward Police Office, Waling.",
#        'Khabang, Nepal', 'Khaptad VDC in Achham district.', 'Dumre',
#        'base of Mt Annapurna South at Narchyang VDC',
#        'Bhimad Bazaar in Tanahun', 'Dhuseni Shivalaya, Kavre, Nepal',
#        'Mahakali Hwy 10200', 'Kusma Municipality-1, Maldhunga',
#        'East-West highway(H01), Dauune Hill(?), Nawalparasi district ',
#        'Hetuda, Kogate', 'Thumki village (200 km northwest of Katmandu)',
#        'road between Jumla and Surkhet, Dailekh and Kalikot districts, Karnali and Bheri provinces',
#        'Mankha-1, Lampate(?), Sindhupalchok district',
#        'Udayapur district', 'Nuwakot district in Central Nepal',
#        'Ranchuli, Kalikot',
#        'Prithvi Highway at Bandipur-8 in Tanahu district',
#        'Khamlalung 57500, Nepal',
#        'Mal Dhunga-Beni Road section in Parbat',
#        'Bijuwar, Pyuthan, Rapti Zone',
#        'Maldhunga(?)-Beni rd, Jugedhara(?), Majhfant(MajphantMallaj) VDC, Parbat district, near Myagdi(?)',
#        'Bhimad-8 and Jemune-6', 'Bindavasini VDCs, Accham district',
#        'Lahan', 'Putalibazaar Municipality-9',
#        '‘Typical Restaurant’ on the banks of Phewa Lake', 'Karauja VDC',
#        'Bungadobhan, Baglung, Western Region',
#        'Kaphaldanda in Ramche VDC -9',
#        'Gwalichaur, Baglung, Western Region',
#        'Sakla Vdc-1 Laikham In Jajarkot District',
#        'Chipleti Ward Nos 5 And 6 Of Pulachour Vdc In Myagdi District.\xa0',
#        'Sirdibas,Gorkha, Gandaki Zone',
#        'Bijul, Rodidewal-9(Raudidewal VDC), Baitadi district',
#        'Vedetar, Eastern Region', 'Barpak',
#        'Tanahun and Rautahat districts, Prithvi Highway at Bandipur and Mahendra Highway at Dhansar',
#        'Phedikhola(?), Shyangja district', 'Lele',
#        'Jungar-8, Kaulabot, Remote Rolpa District',
#        'Mechi Highway at  Lyangba, Dokhu, Nepal',
#        'Taplejung district, Nepal',
#        'Deurali village, Ward 7(?), Sangja(Syangja) district',
#        'Dalit settlement in Seri VDC-4', 'Bardiya and Gulmi districts',
#        'Dhunpa stream at Dhupu VDC-8, Sankhuwasabha',
#        'Araniko hwy between Tatopani and Bahrabise, Sindhupalchowk, Bagmati',
#        'Rapti Highway, Dang District, Midwestern Region', 'Taplejung',
#        'Darechowk(Darechok), Kahare(Khahare) River, Prithvi highway between Mugling and Narayanghat',
#        'Suikhet in Hemja', 'Thukima-6, Taplejung',
#        'The Mugling-Narayanghat Road Section Near Dasdhunga',
#        'Ladabhir and Sirthauli VDCs in Sindhuli district',
#        'Singdi at Pasgaun VDC in Lamjung district',
#        'Shut down Gaighat-Sanue road sections in Udayapur',
#        'village of Jaleswor (Jaleshwori VDC-2) in Khotang district, about 120 kilometres east of Kathmandu',
#        'Chandi Bhanjyang, Syangja', 'Dadakharka VDC in Dolakha district',
#        'Rukum district in the mid-western mountains',
#        'Sarmoli, Darchula, Nepal', 'Bandipur',
#        'Langtang region north-west of Kathmandu',
#        'Parsyang-5 of Pokhara, Kaski district', 'Khairenitar-Bhimad Road',
#        'Kuwakot, Syangja District', 'Gudel, Solukhumbu District',
#        'Gotri VDC-5(Gotree), Bajura',
#        'Devala village of Gaira VDC-1 in Doti district',
#        'Balchaur, Mugu district',
#        'Prithvi Highway in Gajuri, Dhading District, Nepal', 'Gulmi',
#        'Daud VDC-1', 'Budhigandaki River near Khanibesi',
#        'Miteripul, Chaku, Jhyalebhir, Nayapur, Daklang Paharo and Jhirpu, Tatopani along Araniko Highway',
#        'Sarmoli Vdc', 'Gamgadhi-Nagma\xa0Road',
#        'Batase and Sisne villages, Lelep VDC, ',
#        'Kakanda VDC-7(?), Makwanpur district',
#        'Gumdi-2, Dhading district, 40 km west of Kathmandu',
#        'Chimat village, Mangri, Mugu, Nepal', 'Namunabasti, Dailekh',
#        'Achham', 'Daha Vdc Of Kalikot\xa0',
#        'Ramche, Rasuwa district, Nepal',
#        'Sisneri rd(?), between Hetuda and Pharping',
#        'Pokhara-Baglung highway in Parbat district', 'Bajura',
#        'Bhanumati-8, Damauli',
#        'village of Khara, Rukum district, Kathmandu',
#        'Bahadurpur VDC\xa0, Palpa', 'Rak-2', 'Chitwan',
#        'Marbu Vdc-1, Dolakha', 'Hastichaur VDC-1, Gulmi District, Nepal',
#        'Adhikarichaur-4',
#        'near Sirunga(?) and Deurali(?), Musikot VDC-8, Gulmi',
#        'Malika Vdc, Dailekh District, Western Region', 'Deviisthan-5',
#        'Tarakhola, Baglung, Western Region',
#        'Hemja village, Lekhnath municipality',
#        'Siddhartha Highway, near Siddhababa Temple', 'Chunwang VDC-8',
#        'Nuwakot district', 'Banskharka VDC',
#        'Harkate-Kiteni section of Mechi highway',
#        'power station in Malikabota, Jumla District , Nepal',
#        'Siddhartha Highway at Dovan VDC-5',
#        'District of Palpa, Palung Mainadi-6',
#        'Barbhanjyang VDC-8, Tanahun District',
#        'Prithivi highway at Jogimara, Dhading', 'Sankhuwasabha',
#        'Prithvi Highway, Dhading', 'Kalon cliff in Api Municipality-6',
#        'Pokhara-Baglung road, Armadi(?), Parvat(?), Dhaulagiri(Dhawalgiri)',
#        'near Kamala River and BP Highway, Karkare, Kamalamai, Nepal',
#        'Bajura district',
#        'Tamor River, near Sawadin, Taplejung district, Nepal',
#        'Bukhel VDC-9, Lalitpur district (', 'Changunarayan Temple',
#        'Nuwakot', 'Amargadhi-5, Dadeldhura',
#        'Khayarbas(?), Aaptar, Udayapur', 'Jorayal in Doti', 'Jajarkot',
#        'Marauche Community Forest', 'Dadeldhura',
#        'Darling VDC of Gulmi district', 'Madevdanda of Sisneri',
#        'Mechi Highway, Kolbung VDC,Ilam ', 'Biratnagar', 'Gulmi District',
#        'Phidim-Raanke section of the Mechi Highway at Sandim, Phidim-2, Nepal',
#        'Lalighat Bazzar, Kotwada-6, Kalikot district, Nepal',
#        'Mastamandu village, Dadeldhura district', 'Surkhet',
#        'Hetaunda-Kulekhani-Pharping highway, Sisneri-5',
#        'Sola Bhanjyang, Bhimfedi-5, Makwanpur, Nepal', 'Hugdishir-3',
#        'Argha Village, Pyuthan District', 'Ramidanda',
#        'In Dang near  Babai River', 'Gujar-5 of Rolpa district',
#        'Bhairavsthan of Bhairavsthan VDC and Laghuwa of Deurali VDC',
#        '\xa0Tanahu\xa0',
#        'Fanfane(?), Naglingbang on road between Maldhunga(?) in Parbat and Beni Bazaar in Myagdi, Parbat',
#        'Kerauja, near Budhi Gandaki River',
#        'Dholibari of Gejha VDC-8, Palpa',
#        'Mahankal,  Sindhupalchok District, Nepal',
#        'Hulakdanda village of Bhaluwajor-2 in Ramechhap district, Janakpur Zone',
#        'Pyuthan District',
#        'Jawang, Jogimara VDC-2, Prithvi highway between Muglin and Naubise',
#        nan, 'Janaprabha Higher Secondary School, Liku',
#        'Nawamidanda-2, Panchthar', 'Jirmale, Ilam Province, Nepal',
#        'Ghoratabela', 'Bhoje VDC-6 in Lamjung district',
#        'Sim, Phopli, Pyuthan, Nepal',
#        'Pokhara-Baglung Highway, Betani of Tilahar VDC in Parbat district',
#        'Parbat', 'Magpa In\xa0Khotang District In Eastern Nepal',
#        'Hetauda-Kulekhani rd, Naryani province',
#        'Mahakali river at Bangabagad',
#        'Sukla Gandaki Municipality-12, Tanahun',
#        'Parbat, huwas, Mardikhola',
#        'Shut down Ghurmi-Okhaldunga, Okhaldhunga-Rumjatar, Okhaldunga-Solu in Okhaldhunga',
#        'Marpak VDC, Dhading district',
#        'Rakachuli Village, Nawalparasi, Western Region',
#        'primary health centre in the northern Kolti', 'Nala of Tukuchha',
#        'Neta, Rajwara VDC ward number 3, Pyuthan, Nepal', 'Shaktikhor-2',
#        'Ainapahara in Anbukhaireni Municipality-6',
#        'khukondole, Tatopani',
#        'Dailekh -Surkhet Section, Karnali Highway Bound For Jumla And Kalikot',
#        'Okhaldhunga district', 'Linkhim, Taplejung, Nepal', 'Phedi',
#        'Tanahun', 'Hamang VDC, Pyang, Mabu, Sobada Magalbare, Ilam',
#        'Dankhila and Betini in Bala VDC-8, Sankhuwasabha, Kosi Zone',
#        'Narayanghat-Muglin Highway at Kalikhola, Chitwan, Nepal',
#        'Daud VDC-3', 'Sukaunda hill at Kulekhani', 'Luwa Khola',
#        'Buchi Village, Jagannath Vdc-5', 'Baluwa bazaar at Simjung-9',
#        'Kathmandu', 'Dahachaur of Sukatiya-8',
#        'Darau River(?), Syangjha(Syangja) district',
#        'Lamosanghu Jiri and Pushpa Lal road sections(?), Bhirkot VDC, Halhale(?), Dolakha district',
#        'Sattale of Tulsipur Municipality-1 along the Rapti Highway',
#        'Narayangadh-Muglin road at Seti Dovan',
#        'Majhkot village,  Lamjung district, Nepal',
#        'Siddhababa, Donovan-5(?), Siddhartha highway between Tansen and Butwal',
#        'Birgha VDC(Birgha Archale VDC), Syangja district', 'Narayani',
#        'Malikarjun, Darchula, Nepal',
#        'Rakhu VDC in Kalikot district, Karnali',
#        'Bharta VDC, Kalikot district',
#        'Bastitar village(?), Mahankal VDC, Sinhupalchowk district',
#        'Hetauda-Kulekhani road', 'Taman, Baglung, Western Region',
#        'Rajali, Badimalika Municipality, Bajura, Nepal',
#        'trail between Phillim and Lokpa',
#        'Narad Mani Thulung Highway at  Tiwari Bhanjyang , Bhojpur, Nepal',
#        'Laaduk VDC in Dolakha district',
#        'Bobang Vdc, Baglung, Western Region',
#        'Modikhola Hydropower Project',
#        'Salyan-Dang rd, Kothari Khola(?), Dhanwang VDC-7, Salyan',
#        'Parbat district', 'Sukariya(?), Bharta(Marta) VDC-1, Kalikot, ',
#        'Salleri, Phakhel VDC-3\xa0', 'Bungtang, Nuwakot, Nepal',
#        'Dhading, katmandu', 'Dana village, Myagdi',
#        'Khadkha Tole(?), Chittapol(Chitpol) VDC(?), Bhaktapur district',
#        'Khanichhap, Palpa District',
#        'Prasyang of Pokhara-5 in Kaski district, Pokhara',
#        'Narjamandap VDC-7,Pauwathok of Nuwakot',
#        'Bahuban, Irautar-8, Ilam',
#        'Rasuwagadhi customs, Timure, Rasuwa district, Nepal',
#        'Jugepani of Daduwa VDC, Ramechhap',
#        'Betani Of Tilahar Vdc In Parbat', 'Khotang district',
#        'Sattale, Rapti highway, between Dang and Salyan, Tulsipur municipality, Rapti',
#        'Ghattekhola, Timure',
#        'Pokhara-Baglung-Jomsom road at Mauribhir and Beteni of Tilahar VDC',
#        'Balong Palpa-Butwal segment of Siddhartha Highway',
#        'Simaltal(?), on Prithvi hwy, Kabilas VDC, Chitwan',
#        'Mugling-Narayanghat rd in Kerabari(?), Kabilas-5(?), Chitwan',
#        'Purtingkada village (320 kilometers west of the capital, Katmandu)',
#        'Damauli village, Tanahun district', 'Narayani Riverside Resort',
#        'Ullikhola(?), Ridi-Wamitaksar rd, Gulmi district',
#        'Prithvi hwy, Daraipadhera Vyas(?), Tanahun',
#        'Darechok village, on Prithvi hwy, between Mugling and Maleku(Malekhu)(?) Fisling, Chitwan district or Dhading district',
#        'Jayaram-Diktel road in Khotang',
#        'Butwal-Palpa, Palpa-Ramdi, and Tansen-Tamghas sections of Siddhartha Highway',
#        'Baramchi VDC-1 in Khamare', 'Baglung-Burtibang(Burtiwang) rd',
#        'Bhadaure VDC in Kaski district',
#        'Keyarpani of Soti Bazaar in Thumi VDC',
#        'Khundi Khola (River) at Ghan Pokhara Vdc-8', 'Saptari district ',
#        'Pakuwa in Parbat district', 'Baitadi-Darchula\xa0Road\xa0',
#        'Dhungre, Daldale-Bulingtar road, Nepal',
#        'Pala VDC-8 of Baglung district ',
#        'Tamti, Jumla District, Mid-Western Region',
#        'Sadewa VDC-3 of Taplegunj(Taplejung)', 'Dhading', 'Baitadi',
#        'Waglihang of Punja VDC-3, Pyuthan, Nepal',
#        'Mumra Village, Kalikot District, Western Region',
#        'Reep village in Chowk Chisapani VDC-8', 'Phopli, Pyuthan, Nepal',
#        'Ghaiyabari, Tapethok, Taplejung district, Nepal',
#        'Salyan District, mid-western Nepal', 'Pokhara', 'Lumle',
#        'Hurlung Jalapa in Khotang',
#        'Dudilaviti Vdc-2, Chauke, Baglung District', 'Rank VDC-2',
#        'Sainpasela, Malumela Vdc',
#        'Bus park area of Lincon Bazaar in Jiri',
#        'Bitthard Chaur of Sharmili VDC in Darchula',
#        'Lampata of Babiyachaur VDC-5',
#        'Mulkharka,Kalikasthan-Rasuwagadhi road, Rasuwa district , Nepal',
#        'Bhagwati forest(?), Mahadevpuri VDC, Banke district',
#        'rural roads in Myagdi district to Beni',
#        'East-West highway at Dumkibas, Nawalparasi district ',
#        'Khimti-Those Road at Namadi, Ramechhap District, Nepal',
#        'Kalika Secondary School In Kapurkot Of Dhanwang Vdc',
#        'Karnali Highway, Near Manma',
#        'Jhusma   along the Siddhartha Highway, Dobhan VDC 1, Palpa, Nepal',
#        'Shreekot, 600 km west of Kathmandu', 'Jogbuda-4, Malas',
#        'Pandavkhani, Baglung, Western Region',
#        'Asigram-9 Bhetagaun, Dadeldhura',
#        'Pokari village(?), Pokhari Sagarmarth VDC, near Mesirkha(?) and Charpane(?), Udayapur district',
#        'Syaule bazaar, Ruku VDC, Kalikot district (found location for Raku in Kalikot)',
#        'Sadi VDC, Pyuthan district', 'Khimti Village', 'Syalapakhala VDC',
#        '\xa0Prithvi Highway,Titrang,Mauwakhola, Jogimara VDC-2',
#        'Alamdevi Vdc, Syangja',
#        'Pokhara and Sarankot VDC, Kaski District', 'Baglung',
#        'Araniko hwy to villages Bahrabise(Barabise), Lamo Sanghu(Lamosanghu), and Kadi Chaur(Khadichaur), Sindhupalchowk',
#        'Mankha', 'Mechi Highway',
#        'Siddheshwor-9, Baitadi, Western Region',
#        'Sisuwa and Tamku VDCs in the northern part of Sankhuwasabah',
#        'Bolde of Mahankal VDC-6 in Sindhupalchok district',
#        'Sandepani VDC, Kailali district', 'Mustang, Myagdi',
#        'Dhuskun Of Sindupalchowk District', 'Beni-Maldhunga road at Pang',
#        'Budhanilakantha in Kathmandu district', 'Manma',
#        'Sipirang river(?), Dolakha district',
#        'Araniko Highway between Barhabise and Tatopani in Sindhupalchok district',
#        'Chyamrangbesi VDC-1 in Kavre district', 'Kailali',
#        'Shera village, Mugu district ',
#        'Mattikhan(?), Kristinachnaichaur VDC-9(?), Khisti area(?), Kaski district',
#        'Road between Barpak and Muchok',
#        'Maglungkhola Hydro Project, Gumda, Nepal',
#        '(Landslips occurred in Pokhari, Arkhala, Dhugre, Kamalikot) Kawasoti',
#        'Gahate village, Mijuredanda, Kaski district',
#        'Ward No 4 and 5 of Sankhuwa Khola VDC(?), Sankhuwasabha',
#        'Pasang Lhamu Highway (Linking Rasuwa With Kathmandu), Along Ramche And Mulharka Sections',
#        'Jagannath village, Bajura District',
#        'Jharlang VDC of Northern Dhading district, Sumchet, Ward No. 8',
#        'Chokchissapani VDC-9, Tanahun District',
#        'Madi River, Thumkodanda-9(Thumakodada), Sildjure(Sildujure), Kaski',
#        'Kerauja-3, Gorkha district, Nepal', 'Western Nepal',
#        'Rasnalu VDC-6,Darkha,Ramechhap district',
#        'Thade Rivulet at Simkharka of Maijhuwa-4',
#        'Sisuwakhola, Masyam-5', 'Sekham, Syangja District',
#        'Dibrung-3 in Galcheda in Gulmi district',
#        'Lakuridaanda, Bhimeshwar Municipality-9, Dolakha',
#        'Tutung in Mudi-8  http://kathmandupost.ekantipur.com/news/2015-07-30/six-dead-in-myagdi-landslides.html',
#        'Syaphrubesi-Rasuwagadhi road at Ling Ling',
#        'Tamku-8, Sankhuwasabha', 'Katunje VDC in Dhading district ',
#        'Talamarang Bazaar-Batase road at Jagarkot',
#        'Sulichaur village,Nepal', 'Dhankuta',
#        'Thapakhana village in Parbat (Parvat) district',
#        'Biswakharka Village in Gulmi', 'Sanfe-Mangalsen road',
#        'Gorusinge-Sandhikharkha Road',
#        'water pipeline to Dipayal, Pipalla bazaar(?), and Rajpur(?) in Doti, from Salenigad(?), Seti',
#        'Far-Western Development Region', 'Budhimorang, Eastern Region',
#        'Bartung-Ramdi Section, Siddhartha Highway', 'Taplejung district',
#        'Nar VDC', 'Khotang', 'Dikhurpokhari VDC', 'Arghakhanchi',
#        'Siddhartha hwy, Jagatradevi VDC, between Palpa and Syangja',
#        'Chaurikharku, Solukhumbu District',
#        'Hotel En Route To Kalikot District, Northwestern Region',
#        'Tarebhir cliff, near Gokarna forest, northeast of Kathmandu',
#        'Mid-Hills Highway, Myanglung In Terhathum To Chiyobhanjyang',
#        'Pharping-Kulekhani road in Phakel, Makwanpur District, Nepal',
#        'Ratmata-5, Jhagajholi, Sindhuli',
#        'Goethe Bajar, Khatamma, Bhojpur', 'Dhupu VDC\xa0,  ',
#        'Muna-4 VDCs of Myagdi district',
#        'north of Pattal Bhumeshwor, situated at Basulinga VDC of Baidati district',
#        'Muglin(Mugling)-Naubise part of Prithvi highway,',
#        'at Mauribhir along the Pokhara -Baglung Highway',
#        'Narad Mani Thulung Highway at Bhaisipankha, Bhojpur, Nepal',
#        'Siddhesory VDCs and Bindavasini VDCs villages, Accham district',
#        'Khadipakha, Maharajgunj, Kathmandu', 'Rural roads in Palpa',
#        'Thaladanda, Barhabise, Sindhupalchok, Nepal',
#        '\xa0Pokharibhanjyang VDC-1 in Tanahun district\xa0',
#        'Tansen-Tamghas Section, Siddhartha Highway', 'Tanahun district',
#        'near the Kaligandaki River bank at Baribani of Manjhfant, Parbat, Nepal',
#        'Shut down Bhojpur-Chyandanda, Bhojpur-Leguwa, Satighat-Dingla, in Bhojpur',
#        'Dhurkot Village, Nawalparasi, Western Region', 'Sertung',
#        'Chokati Of Sindupalchowk District', 'Kotjahari VDC of Rukum',
#        'Araniko hwy, between Bandeu and Tatopani, Bagmati',
#        'Langtang Valley', 'Bala VDC-5 of Sankhuwasabha district ',
#        'Between Mungling and Narayanghat',
#        'Kumal VDC, Kalikot district (located Kumalgaun, which may be the same location but could not confirm)',
#        'Ridi-Rudraweni(?) rd, Saghure(?), Gulmi district', 'Finam-6',
#        'KI Singh Highway',
#        'Bengri village(?), Debisthan (Devsthan) VDC(?), taken to hospital at Burtiwang, western Baglung district',
#        'Modikhola Hydro Project', 'Mulghat Of Dhankuta',
#        'Dadeldhura and Baitadi, Kailali',
#        'Keramja village in Manaslu region of Gorkha',
#        'Kalikot district and Manma VDC', 'Dolakha',
#        'Ramche-8 of Sindhupalchok',
#        'Mechi Highway at Siteni of Kolbu-9 (Kolbung??)',
#        'Dang-Kapilvastu section of East-West highway(Mahendra Rajmarg HO1), Dobato(?), Kapilvastu district, near Bhaluwang(?)',
#        'Neta in Gulmi district', 'Diktel-Lamidanda road in Khotang',
#        'Amkot in Brahmatola VDC ward-2 ', 'Mahabharat, Eastern Region',
#        'Dhalkedanda in Byasi VDC-1, Bajhang', 'Kolti, Bajura District',
#        'Baglung district, Chauradi village',
#        'Siddhababa in Palpa district', 'Sindupalchowk',
#        'Chaurikharka, Solukhumbu district, Nepal', 'Rolpa', 'Surkhet ',
#        'Chukjhad, Kanda, Bajhang District, Nepal',
#        'Saghutar in Rammechap District',
#        'Rayal VDC-1. Jethara, Bajhang district',
#        'Siddhicharan Highway in Siddhicharan Municipality-4, Okhaldhunga District, Nepal',
#        'Naubise-Simbhanjyang stretch of the Tribhuwan Highway',
#        'Devisthan, Baglung, Western Region',
#        'Pasang Lhamu Highway at Ramche', 'Sapatakoshi Bridge',
#        'village of Kotbada, Salyan district, Kathmandu',
#        'Kuntiwandali-3, Accham, Western Region',
#        'Surkhet-Jumla road section along the Karnali highway, Kalikot (difficult to find place on road, found relative mid-section)',
#        'along Narayangadh-Muglin, Jalbire, Nepal',
#        'Bairagi Thanti Bazaar',
#        'Gulmi-Ridi-Tamghas route in Resunga Municipality-15',
#        'Bhakimli Vdc-8, Myagdi District', 'Irautar, Ilam Province, Nepal',
#        'Naubishe of Sundarpuri Village Development Committee (VDC) in Nuwakot district',
#        'Diktel-Bhojpur road in Khotang',
#        'Birtamod village of Belkot VDC-1 in Nuwakot district',
#        'Ghorahi-Holeri(?) section of East-West highway(H01), Dang/Rolpa districts, Rapti',
#        'Siddhababa in the Butwal-Palpa section of the Siddhartha Highway ',
#        'Sakla-3', 'Nagliwang VDC-9 of Parbat district, Baglung',
#        'Gamkhar VDC in Nuwakot district',
#        'near landfill near Sisdole and Okharpauwa, Kathmandu valley',
#        '9 km from Melamchi, Road between Kathmandu and Melamchi',
#        'Gorkha', 'Phaleni VDC in Lamjung',
#        'Narayangadh-Muglin road section at Panch Kilo of Chandibhanjyang VDC of Chitwan',
#        'Chautara, Liping bazaar of Tatopani VDC of Sindhupalchok district',
#        'Rangrung Hydropower Project at Barpak VDC',
#        'Khadichowr village(?), Mankha VDC, Sinhupalchowk district',
#        'Bhatta VDC-2, Kalikot District',
#        'Upper Madi hydroelectric project', 'Chinnebas, Syangja District',
#        'Sindhupalchowk', 'Prithvi Hwy, Pinda, Dhading district, nepal',
#        'Beni-Jomson Road, Myagdi',
#        'Gulmi, Arghakhanchi and Palpa districts, Lumbini zone',
#        'Satpatre or Nautale jungle(?), Tapethok VDC or Lelep VDC, Taplejung district',
#        'Dumre-Besisahar Road',
#        'Torakhet, Bhakimli-9, Myagdi district, Nepal',
#        'Tipling Ward, Dhading District', 'Limi of Humla',
#        'Hukam VDC-7, Rukum', 'Pipaldanda, Palpa District',
#        'Kathare in Barbhanjyang VDC-8',
#        'Simaltar in Chandibhanjyag VDC-9, Jalbire on Narayangadh-Mugling stretch of the road',
#        'Dumre-Bandipur Road',
#        'Mechi hwy at Gumbadanda(?), Pauwasartap(Pauwa Sartap) VDC-7(?), Panchthar, between Ilam and Phidim, ',
#        'Mulpani village of Khalanga VDC-3 of Jajarkot district, Bheri zone',
#        'Kulung VDC, Bhojpur district',
#        'Kakurthakur VDC-3 in Sindhuli district',
#        'Mochabari Village, Birkot-8, Palpa', 'Khatma VDC-8, Bhojpur',
#        'Singati', 'Duli Village, Rukum district',
#        'Bung Vdc-9, Solukhumbu District',
#        'Tamadi (??), Waling Municipality, Syangja District, Nepal',
#        'road leading to Patan in Byas,  Tanahun, Nepal',
#        'Beni-Darbang Road Section, Phaparkhet',
#        'Khotang District Prison, Khotang District, Nepal',
#        'Mid-Hill Highway, Dhandedanda, Sindhuli, Nepal',
#        'Charkilo (??), Narayani Zone, Nepal',
#        'Syaphru-Timure road, Briddhim, Nepal',
#        'near Fyanglum, Shyafru-Timure section, Nepal-China Gyirong highway, Nepal',
#        'Okhareni, Tamghas, Nepal', 'Lekhani, Nepal',
#        'Ringlang, Bungadobhan-4 in Baglung district, Nepal',
#        'Khandbari, Nepal', 'Martadi, Seti', 'Shantipur, Nepal',
#        'Dhankuta, Nepal', 'Daman, Narayani Zone, Nepal',
#        'Manasalu Foot Trail, Gorkha, Nepal', 'Darechok, Narayani, Nepal',
#        'Talkot, Bhajang District, Nepal',
#        'Rayale, Panauti Municipality, Nepal', 'Kabilas, Narayani',
#        'Dhansira, Ghyachok, Gandaki',
#        'Pasang Lhamu highway, Rasuwa District, Nepal',
#        'Prithvi Highway, Bajhang, Nepal',
#        'Bagjhora, Narayani Zone, Nepal',
#        'Mid-Hill Postal Highway, Daram River, Manewa, Righa VDC-7, Righa, Nepal',
#        'Barabise, Seti', 'Bamka Bazaar (??), Bajura District, Nepal',
#        'Kushma Municipality – 11 in Parbat along the Pokhara-Baglung road section',
#        'Jiteghat (??), Kotbada, Karnali, Nepal',
#        'Kalikhola (??), Narayani Zone, Nepal',
#        'Mid-Hill Highway, Baglung-Burtibang road, Righa-7, Nepal',
#        'Tatopani, Bagmati', 'Dobhan, Lumbini',
#        'Rutatola-Dhuli road of Chainpur-Taklakot road section along the Seti Lokmarga, Rumaili, Talkot Rural Municipality, Bajhang District, Nepal',
#        'Subeda area, Bahjang district, Nepal',
#        'Narayanghat Mugling Road, Charkilo section, Chitwan',
#        'Araniko Highway, Nepal',
#        'Siddhartha Rajmarg, Dobhan 32907, Nepal',
#        'Tinau rural muncipalty, Dobhan, Nepal.',
#        'Siddhartha Rajmarg, Butwal, Nepal.',
#        'Annapurna rural municipality-3, Beni - Jomsom Rd Beni 33200 Nepal.',
#        'Besisahar - Chame Sadak, Arkhale, Marsyangdi Rural Municipality, Nepal.',
#        'Tansen-Ridi-Tamghas Road, Bhangari, Dubichaur, Resunga 32600, Nepal',
#        'Tansen-Ridi-Tamghas Road, Gulmi, Resunga, Nepal',
#        'Khopang, Gosainkunda Rural Municipality-5, Rasuwa district, Nepal',
#        'Beni, Arthunge, Dhawalagiri',
#        'Mahendra Rajmarg, Kabilas, Narayani',
#        'Kabilas, Narayani. Bharatpur metropolis-29, Ghumaune and Ichhakamana municipality-6, Jalbire',
#        'Ichhakamana Rural Municipality-6, Jalbire',
#        'Besi Shahar-Chame road',
#        ' along the Sanfe-Martadi road section in Bajura',
#        'Athbiskot, Rapti', 'near Thati Bazaar in Jajarkot',
#        'along Kali River between Nazang and Mangti',
#        'Baphukhola, Bagchaur, Saylan, Nepal', 'Barhabise, Bagmati, Nepal',
#        'Nuwakot, Lumbini, Nepal', 'Jajarkot District, Nepal',
#        'Jairigad Hydropower Canal, Dunai, Jajarkot District, Nepal',
#        'Zhangzangbo River, north of Tatopani, Tibet Autonomous Region, China',
#        'Marsyangdi Rural Municipality-3, Lamjung, Nepal',
#        'Sindhupalchok, Central Region'], dtype=object)

# %%
test['location_description'] = test['location_description'].astype(str)
districts = test['location_description']

# %%
for index in districts.index:
    for district in nepal_districts:
        if district in districts[index]:
            districts[index] = district
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
test
# Out:
#     event_year event_month                                        event_title  \
# 0         2009          07                                            Dailekh
# 1         2009          07                                              Kaski
# 2         2009          07                                             Tanahu
# 3         2009          07                                          Kathmandu
# 4         2009          07                                            Syangja
# ..         ...         ...                                                ...
# 582       2016          07                        Zhangzangbo River Landslide
# 583       2016          07                        Zhangzangbo River Landslide
# 584       2018          09                                            Lamjung
# 585       2018          09                                            Lamjung
# 586       2020          09  At Least 11 Dead as Nepal Landslides Destroy H...
#
#                                   location_description landslide_size  \
# 0                                              Dailekh         medium
# 1                                                Kaski         medium
# 2                                               Tanahu         medium
# 3                                            Kathmandu          large
# 4                                              Syangja         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 583  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# 584                                            Lamjung          large
# 585                                            Lamjung          large
# 586                                      Sindhupalchok          small
#
#      fatality_count  injury_count   latitude  longitude
# 0               1.0           0.0  28.837800  81.708000
# 1               3.0           0.0  28.203900  83.980600
# 2               2.0           0.0  27.944700  84.227900
# 3              13.0           0.0  28.000000  85.710000
# 4               5.0           0.0  28.104600  83.879100
# ..              ...           ...        ...        ...
# 582             0.0           0.0  27.978173  85.967825
# 583             0.0           0.0  27.971169  85.954188
# 584             2.0           0.0  28.456039  84.232804
# 585             2.0           0.0  28.296584  84.381872
# 586            11.0           0.0  27.829360  85.545040
#
# [587 rows x 9 columns]

# %%
dist = test['location_description']
distr = test['event_title']
for index in dist.index:
    if dist[index] in nepal_districts:
        distr[index] = dist[index]

for index in distr.index:
    if distr[index] in nepal_districts:
        dist[index] = distr[index]
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
test = test.drop(['event_title'], axis=1)

# %%
test.rename(columns = {'location_description':'district'}, inplace = True)

# %%
test
# Out:
#     event_year event_month                                           district  \
# 0         2009          07                                            Dailekh
# 1         2009          07                                              Kaski
# 2         2009          07                                             Tanahu
# 3         2009          07                                          Kathmandu
# 4         2009          07                                            Syangja
# ..         ...         ...                                                ...
# 582       2016          07  Zhangzangbo River, north of Tatopani, Tibet Au...
# 583       2016          07  Zhangzangbo River, north of Tatopani, Tibet Au...
# 584       2018          09                                            Lamjung
# 585       2018          09                                            Lamjung
# 586       2020          09                                      Sindhupalchok
#
#     landslide_size  fatality_count  injury_count   latitude  longitude
# 0           medium             1.0           0.0  28.837800  81.708000
# 1           medium             3.0           0.0  28.203900  83.980600
# 2           medium             2.0           0.0  27.944700  84.227900
# 3            large            13.0           0.0  28.000000  85.710000
# 4           medium             5.0           0.0  28.104600  83.879100
# ..             ...             ...           ...        ...        ...
# 582          large             0.0           0.0  27.978173  85.967825
# 583          large             0.0           0.0  27.971169  85.954188
# 584          large             2.0           0.0  28.456039  84.232804
# 585          large             2.0           0.0  28.296584  84.381872
# 586          small            11.0           0.0  27.829360  85.545040
#
# [587 rows x 8 columns]

# %%
d = test['district']
count = 0
for index in d.index:
    if d[index] in nepal_districts:
        count += 1
count
# Out:
# 372

# %%
test.to_csv('nepal_data.csv')
