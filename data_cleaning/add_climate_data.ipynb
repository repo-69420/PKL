# %%
import pandas as pd

# %%
df = pd.read_csv('nepal_data.csv')

# %%
nd = df.copy()

# %%
nd
# Out:
#      Unnamed: 0  event_year  event_month  \
# 0             0        2009            7
# 1             1        2009            7
# 2             2        2009            7
# 3             3        2009            7
# 4             4        2009            7
# ..          ...         ...          ...
# 582         582        2016            7
# 583         583        2016            7
# 584         584        2018            9
# 585         585        2018            9
# 586         586        2020            9
#
#                                               district landslide_size  \
# 0                                              Dailekh         medium
# 1                                                Kaski         medium
# 2                                               Tanahu         medium
# 3                                            Kathmandu          large
# 4                                              Syangja         medium
# ...

# %%
nd.columns
# Out:
# Index(['Unnamed: 0', 'event_year', 'event_month', 'district', 'landslide_size',
#        'fatality_count', 'injury_count', 'latitude', 'longitude'],
#       dtype='object')

# %%
nd.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
n_districts = ["Achham","Arghakhanchi","Baglung","Baitadi","Bajhang","Bajura","Banke","Bara","Bardiya","Bhaktapur","Bhojpur","Chitwan","Dadeldhura","Dailekh","Dang","Darchula","Dhading","Dhankuta","Dhanusa","Dolakha","Dolpa","Doti","Gorkha","Gulmi","Humla","Ilam","Jajarkot","Jhapa","Jumla","Kailali","Kalikot","Kanchanpur","Kapilvastu","Kaski","Kathmandu","Kavrepalanchok","Khotang","Lalitpur","Lamjung","Mahottari","Makawanpur","Manang","Morang","Mugu","Mustang","Myagdi","Nawalparasi","Nuwakot","Okhaldhunga","Palpa","Panchthar","Parbat","Parsa","Pyuthan","Ramechhap","Rasuwa","Rautahat","Rolpa","Rukum","Rupandehi","Salyan","Sankhuwasabha","Saptari","Sarlahi","Sindhuli","Sindhupalchwok","Sindhupalchok", "Siraha","Solukhumbu","Sunsari","Surkhet","Syangja","Tanahu","Taplejung","Terhathum","Udayapur"]

# %%
districts = nd['district']

# %%
nd
# Out:
#      event_year  event_month  \
# 0          2009            7
# 1          2009            7
# 2          2009            7
# 3          2009            7
# 4          2009            7
# ..          ...          ...
# 582        2016            7
# 583        2016            7
# 584        2018            9
# 585        2018            9
# 586        2020            9
#
#                                               district landslide_size  \
# 0                                              Dailekh         medium
# 1                                                Kaski         medium
# 2                                               Tanahu         medium
# 3                                            Kathmandu          large
# 4                                              Syangja         medium
# ..                                                 ...            ...
# 582  Zhangzangbo River, north of Tatopani, Tibet Au...          large
# ...

# %%
not_converted = []
for i in range(len(nd)):
    if df['district'][i] not in n_districts:
        not_converted.append(df['district'][i])

# %%
not_converted
# Out:
# ['Pasang Lhamu Highway',
#  'Pasang Lhamu Highway, Nepal',
#  'Jugu, Nepal',
#  'Galeshwor, Beni, Nepal',
#  'Talladehi, Nepal',
#  'Rajwara, Gaumukhi Rural Municipality, Nepal',
#  'Matepani Gupta monastery, Pokhara, Nepal',
#  'Hosrangdi, Mahashila Rural Municipality, Nepal',
#  'Lamachaur, Pokhara, Nepal',
#  'Amden (??), Myadlung Municipality, Eastern Development Region, Nepal',
#  'Jubitha, Nepal',
#  'Pasryanga cliff (??), Pokhara, Nepal',
#  'Khabang, Nepal',
#  'Dumre',
#  'base of Mt Annapurna South at Narchyang VDC',
#  'Dhuseni Shivalaya, Kavre, Nepal',
#  'Mahakali Hwy 10200',
#  'Kusma Municipality-1, Maldhunga',
#  'Hetuda, Kogate',
#  'Thumki village (200 km northwest of Katmandu)',
#  'Khamlalung 57500, Nepal',
#  'Bhimad-8 and Jemune-6',
#  'Bindavasini VDCs, Accham district',
#  'Lahan',
#  'Putalibazaar Municipality-9',
#  '‘Typical Restaurant’ on the banks of Phewa Lake',
#  'Karauja VDC',
#  'Kaphaldanda in Ramche VDC -9',
#  'Vedetar, Eastern Region',
# ...

# %%
data = nd[~nd.district.isin(not_converted)]

# %%
data
# Out:
#      event_year  event_month       district landslide_size  fatality_count  \
# 0          2009            7        Dailekh         medium             1.0
# 1          2009            7          Kaski         medium             3.0
# 2          2009            7         Tanahu         medium             2.0
# 3          2009            7      Kathmandu          large            13.0
# 4          2009            7        Syangja         medium             5.0
# ..          ...          ...            ...            ...             ...
# 580        2018            9       Jajarkot          large             8.0
# 581        2018            9       Jajarkot          large             0.0
# 584        2018            9        Lamjung          large             2.0
# 585        2018            9        Lamjung          large             2.0
# 586        2020            9  Sindhupalchok          small            11.0
#
#      injury_count   latitude  longitude
# ...

# %%
data.rename(columns = {"event_year": "YEAR", "event_month": "MONTH", "district":"DISTRICT"}, inplace=True)
# Out:
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
climate = pd.read_csv('climate_data_nepal_district_wise_monthly.csv')

# %%
cd = climate.copy()

# %%
cd
# Out:
#              DATE  YEAR  MONTH      DISTRICT   LAT   LON  PRECTOT     PS  \
# 0      1981-01-31  1981      1  Arghakhanchi  27.9  83.2    67.31  93.78
# 1      1981-02-28  1981      2  Arghakhanchi  27.9  83.2     3.37  93.52
# 2      1981-03-31  1981      3  Arghakhanchi  27.9  83.2    26.02  93.40
# 3      1981-04-30  1981      4  Arghakhanchi  27.9  83.2    46.15  93.03
# 4      1981-05-31  1981      5  Arghakhanchi  27.9  83.2    69.45  92.75
# ...           ...   ...    ...           ...   ...   ...      ...    ...
# 29011  2019-08-31  2019      8      Udayapur  26.9  86.5     4.46  94.41
# 29012  2019-09-30  2019      9      Udayapur  26.9  86.5     9.93  94.92
# 29013  2019-10-31  2019     10      Udayapur  26.9  86.5     0.28  95.34
# 29014  2019-11-30  2019     11      Udayapur  26.9  86.5     0.04  95.48
# 29015  2019-12-31  2019     12      Udayapur  26.9  86.5     0.35  95.74
#
#         QV2M   RH2M  ...  T2M_RANGE     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# ...

# %%
cd.drop(['DATE', 'LAT', 'LON'], axis=1, inplace=True)

# %%
cd
# Out:
#        YEAR  MONTH      DISTRICT  PRECTOT     PS   QV2M   RH2M    T2M  T2MWET  \
# 0      1981      1  Arghakhanchi    67.31  93.78   5.28  53.09  13.03    3.34
# 1      1981      2  Arghakhanchi     3.37  93.52   5.13  40.88  16.67    2.94
# 2      1981      3  Arghakhanchi    26.02  93.40   5.91  35.84  20.83    4.84
# 3      1981      4  Arghakhanchi    46.15  93.03   6.52  29.81  25.50    5.94
# 4      1981      5  Arghakhanchi    69.45  92.75   9.95  37.25  28.89   12.45
# ...     ...    ...           ...      ...    ...    ...    ...    ...     ...
# 29011  2019      8      Udayapur     4.46  94.41  20.34  85.51  27.01   24.27
# 29012  2019      9      Udayapur     9.93  94.92  18.62  87.16  25.24   22.85
# 29013  2019     10      Udayapur     0.28  95.34  15.04  84.67  22.26   19.44
# 29014  2019     11      Udayapur     0.04  95.48  11.26  73.08  19.96   14.75
# 29015  2019     12      Udayapur     0.35  95.74   6.57  61.07  14.33    6.62
#
# ...

# %%
merge = pd.merge(data, cd, how ='inner', on =['YEAR', 'MONTH', 'DISTRICT'])

# %%
merge
# Out:
#      YEAR  MONTH      DISTRICT landslide_size  fatality_count  injury_count  \
# 0    2009      7       Dailekh         medium             1.0           0.0
# 1    2009      7         Kaski         medium             3.0           0.0
# 2    2009      7     Kathmandu          large            13.0           0.0
# 3    2009      7       Syangja         medium             5.0           0.0
# 4    2011      7  Arghakhanchi         medium             2.0           0.0
# ..    ...    ...           ...            ...             ...           ...
# 253  2018     12        Rasuwa          small             0.0           0.0
# 254  2018     12        Rasuwa          small             0.0           0.0
# 255  2018      9       Nuwakot        unknown             0.0           0.0
# 256  2018      9       Lamjung          large             2.0           0.0
# 257  2018      9       Lamjung          large             2.0           0.0
#
# ...

# %%
merge.to_csv('final.csv')
